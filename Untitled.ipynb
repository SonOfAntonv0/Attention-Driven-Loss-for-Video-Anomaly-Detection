# %%
import numpy as np
import cv2
import matplotlib.pyplot as py
# %matplotlib inline

# %%
cv2.imshow()

# %%
ps_wo=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/')

# %%
adam=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Adam_00_iters_EvoNormS0.npy')
adab=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Adabelief_1000_iters_EvoNormS0.npy')
alig=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Alig_1000_iters_EvoNormS0.npy')

# %%
x=list(range(1,101))

# %%
py.plot(x,adam)
py.plot(x,adab)
py.plot(x,alig)
py.legend(['Adam','Adabelief','ALI-G'])
py.xlabel('Iterations')
py.ylabel('Loss')
py.title(' Loss Trend with EvoNorm, Ped2')
# Out:
# Text(0.5, 1.0, ' Loss Trend with EvoNorm, Ped2')

# %%
adam1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/Adam_600_iter.npy')
adam=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/Adam_600_iter_test.npy')
#adab1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Adabelief_1000_iter.npy')
#alig1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Alig_100_iter.npy')

# %%
py.plot(x,adam1)
py.plot(x,adam)
py.legend(['Train Loss','Test'])
py.xlabel('Iterations')
py.ylabel('Loss')
py.title(' Loss Trend')
# Out:
# Text(0.5, 1.0, ' Loss Trend')

# %%
adam1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Adam_1000_iter.npy')

# %%
py.plot(x,adam)
py.plot(x,adam1)
py.legend(['w EvoNorm','w/o EvoNorm'])
py.xlabel('Iterations')
py.ylabel('Loss')
py.title(' Loss Trend for Adam, Ped2')
# Out:
# Text(0.5, 1.0, ' Loss Trend for Adam, Ped2')

# %%
alig1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Alig_1000_iter.npy')

# %%
py.plot(x,alig)
py.plot(x,alig1)
py.legend(['w EvoNorm','w/o EvoNorm'])
py.xlabel('Iterations')
py.ylabel('Loss')
py.title(' Loss Trend for ALI-G, Ped2')
# Out:
# Text(0.5, 1.0, ' Loss Trend for ALI-G, Ped2')

# %%
py.plot(x,adam1)
py.plot(x,adab1)
py.plot(x,alig1)
py.legend(['Adam','Adabelief','ALI-G'])
py.xlabel('Iterations')
py.ylabel('Loss')
py.title(' Loss Trend w/o EvoNorm, Ped2')
# Out:
# Text(0.5, 1.0, ' Loss Trend w/o EvoNorm, Ped2')

# %%
adam=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Adam_600_iter_EvoNorm.npy')
adab=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Adabelief_600_iter_EvoNorm.npy')
alig=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Alig_600_iter_EvoNorm.npy')

# %%
x=list(range(1,601))

# %%
adam1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Adam_600_iter.npy')
adab1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Adabelief_600_iter.npy')
alig1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Alig_600_iter.npy')

# %%
y_lims=[]

# %%
fig,ax=py.subplots(1,2,figsize=(20,8))
ax[0].plot(x,adam)
ax[0].plot(x,adab)
ax[0].plot(x,alig)
ax[0].legend(['Adam','Adabelief','ALI-G'])
ax[0].set_xlabel('Iterations')
ax[0].set_ylabel('Loss')
ax[0].set_title(' Loss Trend with EvoNorm, Avenue')
ax[0].set_ylim((y_lims[0],y_lims[-1]))
ax[1].plot(x,adam1)
ax[1].plot(x,adab1)
ax[1].plot(x,alig1)
ax[1].legend(['Adam','Adabelief','ALI-G'])
ax[1].set_xlabel('Iterations')
ax[1].set_ylabel('Loss')
ax[1].set_title(' Loss Trend w/o EvoNorm, Avenue')
ax[1].set_ylim((y_lims[0],y_lims[-1]))
# Out:
# (-0.0032608091831207303, 2.040824967622757)

# %%
y_lims.sort()

# %%
fig,ax=py.subplots(1,3,figsize=(20,8))
ax[0].plot(x,adam)
ax[0].plot(x,adam1)
ax[0].legend(['w EvoNorm','w/o EvoNorm'])
ax[0].set_xlabel('Iterations')
ax[0].set_ylabel('Loss')
ax[0].set_title(' Loss Trend for Adam, Avenue')
ax[0].set_ylim((y_lims[0],y_lims[-1]))
ax[1].plot(x,alig)
ax[1].plot(x,alig1)
ax[1].legend(['w EvoNorm','w/o EvoNorm'])
ax[1].set_xlabel('Iterations')
ax[1].set_ylabel('Loss')
ax[1].set_title(' Loss Trend for ALI-G, Avenue')
ax[1].set_ylim((y_lims[0],y_lims[-1]))
ax[2].plot(x,adab)
ax[2].plot(x,adab1)
ax[2].legend(['w EvoNorm','w/o EvoNorm'])
ax[2].set_xlabel('Iterations')
ax[2].set_ylabel('Loss')
ax[2].set_title(' Loss Trend for Adabelief, Avenue')
ax[2].set_ylim((y_lims[0],y_lims[-1]))
# Out:
# (-0.0032608091831207303, 2.040824967622757)

# %%
adam=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Adam_600_iter_BatchNorm.npy')
adab=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Adabelief_600_iter_BatchNorm.npy')
alig=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Alig_600_iter_BatchNorm.npy')

# %%
adam1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Adam_600_iter.npy')
adab1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Adabelief_600_iter.npy')
alig1=np.load('C:/Users/Venky/Documents/Jupyter/Some work v1.2/Mini Project 7th sem/Attention-Driven Loss for Anomaly Detection in Video Surveillance/Codes/Results/plot arrays/Avenue/Alig_600_iter.npy')

# %%
y_lims=[]

# %%
fig,ax=py.subplots(1,2,figsize=(20,8))
ax[0].plot(x,adam)
ax[0].plot(x,adab)
ax[0].plot(x,alig)
ax[0].legend(['Adam','Adabelief','ALI-G'])
ax[0].set_xlabel('Iterations')
ax[0].set_ylabel('Loss')
ax[0].set_title(' Loss Trend with BatchNorm, Avenue')
ax[0].set_ylim((y_lims[0],y_lims[-1]))
ax[1].plot(x,adam1)
ax[1].plot(x,adab1)
ax[1].plot(x,alig1)
ax[1].legend(['Adam','Adabelief','ALI-G'])
ax[1].set_xlabel('Iterations')
ax[1].set_ylabel('Loss')
ax[1].set_title(' Loss Trend w/o BatchNorm, Avenue')
ax[1].set_ylim((y_lims[0],y_lims[-1]))
# Out:
# (-0.0032608091831207303, 2.040824967622757)

# %%
fig,ax=py.subplots(1,3,figsize=(20,8))
ax[0].plot(x,adam)
ax[0].plot(x,adam1)
ax[0].legend(['w BatchNorm','w/o BatchNorm'])
ax[0].set_xlabel('Iterations')
ax[0].set_ylabel('Loss')
ax[0].set_title(' Loss Trend for Adam, Avenue')
ax[0].set_ylim((y_lims[0],y_lims[-1]))
ax[1].plot(x,alig)
ax[1].plot(x,alig1)
ax[1].legend(['w BatchNorm','w/o BatchNorm'])
ax[1].set_xlabel('Iterations')
ax[1].set_ylabel('Loss')
ax[1].set_title(' Loss Trend for ALI-G, Avenue')
ax[1].set_ylim((y_lims[0],y_lims[-1]))
ax[2].plot(x,adab)
ax[2].plot(x,adab1)
ax[2].legend(['w BatchNorm','w/o BatchNorm'])
ax[2].set_xlabel('Iterations')
ax[2].set_ylabel('Loss')
ax[2].set_title(' Loss Trend for Adabelief, Avenue')
ax[2].set_ylim((y_lims[0],y_lims[-1]))
# Out:
# (-0.01144043132662774, 2.174591889232397)

# %%
# Out:
# [-0.01144043132662774,
#  0.011752177029848099,
#  0.05369909815490245,
#  0.1837727054953575,
#  1.0114119354635478,
#  1.6875471137464046,
#  2.1652960255742073,
#  2.174591889232397]
